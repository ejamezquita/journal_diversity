# %%
import numpy as np
import pandas as pd

# %%
src = '../data/Plt_sci_publications_'
file1 = src + 'updated_5.03.csv'
file2 = src + 'missing_records_2009_8.2.22.csv'

data1 = pd.read_csv(file1)
print(data1.shape)

data2 = pd.read_csv(file2)
print(data2.shape)
# Out:
# (292520, 106)
# (4013, 52)

# %%
for i,c in enumerate(data1.columns):
    print(i,c,sep='\t')
# Out:
# 0	Author Full Names
# 1	Article Title
# 2	Journal
# 3	impact factor (2020)
# 4	Author Keywords
# 5	Keywords Plus
# 6	Abstract
# 7	Addresses--all authors
# 8	Nations--all authors
# 9	Corresponding author Addresses
# 10	Corresponding author Nation
# 11	Corresponding author Continent
# 12	Corresponding author global designation
# 13	Email Addresses
# 14	Researcher Ids
# 15	ORCIDs
# 16	Funding Orgs
# 17	Funding Text
# 18	Cited Reference Count
# 19	Times Cited, All Databases
# 20	Publisher
# 21	Publisher City
# 22	Publisher Address
# 23	ISSN
# 24	eISSN
# 25	Publication Date
# 26	Publication Year
# 27	Volume
# 28	Issue
# 29	DOI
# 30	WoS categories
# 31	IDS Number
# 32	UT (Unique WOS ID)
# 33	Pubmed Id
# 34	Open Access Designations
# 35	Open Access simplified
# 36	Unnamed: 36
# 37	Unnamed: 37
# 38	Unnamed: 38
# 39	Unnamed: 39
# 40	Unnamed: 40
# 41	Unnamed: 41
# 42	Unnamed: 42
# 43	Unnamed: 43
# 44	Unnamed: 44
# 45	Unnamed: 45
# 46	Unnamed: 46
# 47	Unnamed: 47
# 48	Unnamed: 48
# ...

# %%
for i,c in enumerate(data2.columns):
    print(i,c,sep='\t')
# Out:
# 0	Author Full Names
# 1	Article Title
# 2	Journal
# 3	impact factor (2020)
# 4	Author Keywords
# 5	Keywords Plus
# 6	Abstract
# 7	Addresses--all authors
# 8	Nations--all authors
# 9	Corresponding author Addresses
# 10	Corresponding author Nation_data
# 11	Corresponding author Continent
# 12	Corresponding author global designation
# 13	Email Addresses
# 14	Researcher Ids
# 15	ORCIDs
# 16	Funding Orgs
# 17	Funding Text
# 18	Cited Reference Count
# 19	Times Cited, All Databases
# 20	Publisher
# 21	Publisher City
# 22	Publisher Address
# 23	ISSN
# 24	eISSN
# 25	Open Access Designations
# 26	Open Access Simple
# 27	Quartile
# 28	Journal location
# 29	Subspecality (JCR)
# 30	Society (Yes or No)
# 31	Name of the society
# 32	Open Access or Not
# 33	Open access fees (USD)
# 34	Publication Date
# 35	Publication Year
# 36	Volume
# 37	Issue
# 38	DOI
# 39	WoS Categories
# 40	IDS Number
# 41	UT (Unique WOS ID)
# 42	Pubmed Id
# 43	Corresponding_author_last_name
# 44	first and last names
# ...
