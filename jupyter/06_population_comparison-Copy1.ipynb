# %%
import numpy as np
import pandas as pd
import glob
import os
from importlib import reload
from sklearn.metrics.pairwise import haversine_distances

# %%
filename = '../data/geonames_countryInfo.txt'
meta = pd.read_csv(filename, skiprows=49, usecols=[0,1,4,5,6,7,8,9], keep_default_na=False)
isos = pd.unique(meta['ISO'])

meta.head()
# Out:
#   ISO ISO3               Country           Capital  Area(in sq km)  \
# 0  AD  AND               Andorra  Andorra la Vella           468.0
# 1  AE  ARE  United Arab Emirates         Abu Dhabi         82880.0
# 2  AF  AFG           Afghanistan             Kabul        647500.0
# 3  AG  ATG   Antigua and Barbuda        St. John's           443.0
# 4  AI  AIA              Anguilla        The Valley           102.0
#
#    Population Continent Income
# 0       77006        EU     HI
# 1     9630959        AS     HI
# 2    37172386        AS     LO
# 3       96286        NA      X
# 4       13254        NA      X

# %%
filename = '../data/geonames_disputed_territories.csv'
conflict = pd.read_csv(filename, keep_default_na=False)
print(conflict.shape)
conflict.head()
# Out:
# (2, 4)
#   ISO     name claimed_by_iso claimed_by_name
# 0  CY   Cyprus             TR          Turkey
# 1  UA  Ukraine             RU          Russia

# %%
filename = '../data/geonames_dependent_countries_territories.csv'
depend = pd.read_csv(filename, keep_default_na=False)
print(depend.shape)
depend.head()
# Out:
# (51, 6)
#   ISO            name  depends_from featurecode children notes
# 0  AI         Anguila            GB        PCLD        -
# 1  AQ      Antarctica  12 countries        ADM1        -
# 2  AS  American Samoa            US        ADMD     ADMD
# 3  AW           Aruba            NL       PCLIX        -
# 4  AX   Åland Islands            FI        ISLS        -

# %%
filename = '../data/geonames_cities500.txt'
popd = pd.read_table(filename, header=None, dtype={10:'str', 13:'str'}, keep_default_na=False)
print(popd.shape)
popdcolumns = ['geonameid', 'name', 'asciiname', 'alternatenames',
               'latitude', 'longitude', 'feature_class', 'feature_code',
               'country_code', 'cc2', 'admin1_code', 'admin2_code', 'admin3_code',
               'admin4_code', 'population', 'elevation','dem', 'timezone', 'modification_date']
popd.columns = popdcolumns
popd = popd.loc[:, ['asciiname', 'country_code', 'population', 'latitude', 'longitude']]
popd = popd[popd['population'] > 100]
print(popd.shape)

popd.head()
# Out:
# (198934, 19)
# (166795, 5)
#           asciiname country_code  population  latitude  longitude
# 0  Andorra la Vella           AD     20430.0  42.50779    1.52109
# 1           Arinsal           AD      1419.0  42.57205    1.48453
# 2           Canillo           AD      3292.0  42.56760    1.59756
# 3         El Tarter           AD      1052.0  42.57952    1.65362
# 4            Encamp           AD     11223.0  42.53474    1.58014

# %% [markdown]
# # Connection to research cities

# %%
src = '../results/'
dst = '../plots/'

filename = src + 'tally_merged_locations.csv'
auth = pd.read_csv(filename)

print(auth.shape)
countries = pd.unique(auth.country)
# Out:
# (6424, 6)

# %%
country = 'Botswana'
if country in ['England', 'North Ireland', 'Scotland', 'Wales']:
    iso = 'GB'
else:
    iso = meta[meta['Country'] == country]['ISO'].values[0]
print(country, iso)
# Out:
# Botswana BW

# %%
resc = auth[auth['country'] == country].copy()
resloc = resc.loc[:, ['latitude', 'longitude']].values
resloc = np.deg2rad(resloc)

isocolonies = depend[depend['depends_from']==iso]['ISO'].values
isoconflict = conflict[conflict['claimed_by_iso']==iso]['ISO'].values

if len(isocolonies) > 0:
    colonies = []
    for isoc in isocolonies:
        colonies.append(popd[popd['country_code'] == isoc].copy())
    colonies.append(popd[popd['country_code'] == iso].copy())
    popc = pd.concat(colonies).sort_values(by='population', ascending=False).copy()
elif len(isoconflict) > 0:
    conflicts = []
    for isoc in isoconflict:
        conflicts.append(popd[popd['country_code'] == isoc].copy())
    conflicts.append(popd[popd['country_code'] == iso].copy())
    popc = pd.concat(conflicts).sort_values(by='population', ascending=False).copy()
else:
    popc = popd[popd['country_code'] == iso].copy().sort_values(by='population', ascending=False)
    
poploc = popc.loc[:, ['latitude', 'longitude']].values
poploc = np.deg2rad(poploc)
print(popc.shape)

r2p = haversine_distances(resloc, poploc)
r2p *= 6371000/1000
print(r2p.shape)
# Out:
# (105, 5)
# (7, 105)

# %%
popc
# Out:
#            asciiname country_code  population  latitude  longitude
# 15691       Gaborone           BW    208411.0 -24.65451   25.90859
# 15689    Francistown           BW     89979.0 -21.17000   27.50778
# 15747     Molepolole           BW     63248.0 -24.40659   25.49508
# 15771  Selebi-Phikwe           BW     53727.0 -21.97895   27.84296
# 15736           Maun           BW     49945.0 -19.98333   23.41667
# ...              ...          ...         ...       ...        ...
# 15706        Kavimba           BW       566.0 -18.01667   24.60000
# 15781         Toteng           BW       556.0 -20.38333   22.95000
# 15682       Bokspits           BW       547.0 -26.90000   20.70000
# 15751         Moremi           BW       546.0 -22.57234   27.45058
# 15707     Kgaphamadi           BW       544.0 -24.53778   25.92750
#
# [105 rows x 5 columns]

# %%
resc
# Out:
#      incountry_rank   country                       location  score  \
# 458               0  Botswana             Gaborone, Botswana     89
# 459               1  Botswana                 Maun, Botswana     14
# 460               2  Botswana              Palapye, Botswana      8
# 461               3  Botswana            Mmadinare, Botswana      2
# 462               4  Botswana                Kanye, Botswana      1
# 463               5  Botswana  Sebele, Francistown, Botswana      1
# 464               6  Botswana               Ghanzi, Botswana      1
#
#       latitude  longitude
# 458 -24.628208  25.923147
# 459 -19.995262  23.418077
# 460 -22.551487  27.114710
# 461 -21.881060  27.751381
# 462 -24.988061  25.343020
# 463 -21.166100  27.514360
# 464 -21.696099  21.648186

# %%
cdata = auth[auth['country'] == country].copy()
metro = np.zeros(len(r2p), dtype=int)
matchs = ['' for i in range(len(metro))]
isom = ['' for i in range(len(metro))]
diffs = np.zeros(len(metro))

for i in range(len(metro)):
    argmatch = np.argmin(r2p[i])
    diffs[i] = r2p[i, argmatch]
    matchs[i] = popc.iloc[argmatch, 0]
    isom[i] = popc.iloc[argmatch, 1]
    metro[i] = popc.iloc[argmatch, 2]
    popc.iloc[argmatch, 2] = 0
for i in range(len(metro)):
    if isom[i] not in isoconflict:
        argmatch = np.nonzero(r2p[i] < 35)[0]
        matches = popc.iloc[argmatch]
        isomatches = matches[matches['country_code'] == isom[i]]
        totmetro = np.sum(isomatches['population'].values)
        metro[i] += totmetro
        popc.loc[isomatches.index, 'population'] = 0

cdata['matched_iso'] = isom
cdata['matched_pop'] = matchs
cdata['population'] = metro
cdata['difference'] = diffs

# %%
cdata
# Out:
#      incountry_rank   country                       location  score  \
# 458               0  Botswana             Gaborone, Botswana     89
# 459               1  Botswana                 Maun, Botswana     14
# 460               2  Botswana              Palapye, Botswana      8
# 461               3  Botswana            Mmadinare, Botswana      2
# 462               4  Botswana                Kanye, Botswana      1
# 463               5  Botswana  Sebele, Francistown, Botswana      1
# 464               6  Botswana               Ghanzi, Botswana      1
#
#       latitude  longitude matched_iso    matched_pop  population  difference
# 458 -24.628208  25.923147          BW       Gaborone      357616    3.273878
# 459 -19.995262  23.418077          BW           Maun       49945    1.334920
# 460 -22.551487  27.114710          BW        Palapye       39569    1.223745
# 461 -21.881060  27.751381          BW  Selebi-Phikwe       55652   14.412236
# 462 -24.988061  25.343020          BW          Kanye       67615    2.586730
# 463 -21.166100  27.514360          BW    Francistown      112413    0.808443
# 464 -21.696099  21.648186          BW         Ghanzi       10977    0.313322

# %%
cdata[cdata['population'] < 10].sort_values(by='matched_pop')
# Out:
#      incountry_rank   country             location  score   latitude  \
# 459               1  Botswana       Maun, Botswana     14 -19.995262
# 461               3  Botswana  Mmadinare, Botswana      2 -21.881060
#
#      longitude matched_iso    matched_pop  population  difference
# 459  23.418077          BW           Maun           0    1.334920
# 461  27.751381          BW  Selebi-Phikwe           0   14.412236

# %%
cdata[cdata['matched_pop'] == "Cheorwon"]
# Out:
# Empty DataFrame
# Columns: [incountry_rank, country, location, score, latitude, longitude, matched_iso, matched_pop, population, difference]
# Index: []

# %%
cdata[cdata['matched_iso'] != iso]
# Out:
# Empty DataFrame
# Columns: [incountry_rank, country, location, score, latitude, longitude, matched_iso, matched_pop, population, difference]
# Index: []

# %%
cdata.sort_values(by = 'difference', ascending=False).head(15)
# Out:
#       incountry_rank      country                                   location  \
# 5231              47  South Korea                   Sejong City, South Korea
# 5243              59  South Korea    Mitynang Si, Gyeongsangnam, South Korea
# 5244              60  South Korea                       Hamyang, South Korea
# 5232              48  South Korea       Jangheung, Jeollanam Do, South Korea
# 5239              55  South Korea         Hadong Gun, Gyeongnam, South Korea
# 5215              31  South Korea            Eumseong, Chungbuk, South Korea
# 5217              33  South Korea           Pochon, Gyeonggi Do, South Korea
# 5249              65  South Korea       Seongju, Gyeongbuk Prov, South Korea
# 5233              49  South Korea  Bonghwa Gun, Gyeongsangbuk D, South Korea
# 5214              30  South Korea      Seocheon, Chungcheongnam, South Korea
# 5242              58  South Korea      Cheorwon Gun, Gangwon Do, South Korea
# 5187               3  South Korea                Wanju, Chonbuk, South Korea
# 5237              53  South Korea                         Haman, South Korea
# 5196              12  South Korea          Incheon, Gyeonggi Do, South Korea
# 5204              20  South Korea     Jeongeup Si, Jeollabuk Do, South Korea
#
#       score   latitude   longitude matched_iso  matched_pop  population  \
# 5231     10  35.907757  127.766922          KR    Yeongdong       24154
# 5243      2  35.460600  128.213200          KR  Changnyeong           0
# 5244      2  35.520461  127.725176          KR      Changsu       26463
# 5232      8  34.681686  126.906928          KR      Yeongam       55000
# 5239      3  35.067211  127.751269          KR    Kwangyang       89281
# 5215     60  36.939679  127.690502          KR       Koesan       44461
# 5217     58  37.894915  127.200355          KR       Yangju      179923
# 5249      1  35.919008  128.282974          KR      Waegwan       29691
# 5233      6  36.893093  128.732375          KR        Eisen       84625
# 5214     71  36.080331  126.691328          KR       Gunsan      243406
# 5242      2  38.146609  127.313226          KR     Cheorwon       54040
# 5187   1718  35.891275  127.253895          KR        Wanju      826706
# 5237      3  35.272559  128.406480          KR        Naeso       80987
# 5196    421  37.413800  127.518300          KR   Yangp'yong      461893
# 5204    169  35.569885  126.855896          KR     Jeongeup      162143
#
#       difference
# 5231   29.728257
# 5243   27.052663
# 5244   23.725397
# 5232   23.320246
# 5239   17.954987
# 5215   17.064871
# 5217   13.978722
# 5249   13.179996
# 5233   12.028989
# 5214   11.453856
# 5242   10.881410
# 5187   10.874373
# 5237   10.615215
# 5196    8.789892
# 5204    6.462640

# %% [markdown]
# # Concatenating all countries

# %%
cdata = []
cnone = []

for i in range(len(countries)):
    country=countries[i]
    if country in ['England', 'North Ireland', 'Scotland', 'Wales']:
        iso = 'GB'
    else:
        iso = meta[meta['Country'] == country]['ISO'].values[0]
        
    resc = auth[auth['country'] == country].copy()
    resloc = resc.loc[:, ['latitude', 'longitude']].values
    resloc = np.deg2rad(resloc)
    
    isocolonies = depend[depend['depends_from']==iso]['ISO'].values
    isoconflict = conflict[conflict['claimed_by_iso']==iso]['ISO'].values

    if len(isocolonies) > 0:
        colonies = []
        for isoc in isocolonies:
            colonies.append(popd[popd['country_code'] == isoc].copy())
        colonies.append(popd[popd['country_code'] == iso].copy())
        popc = pd.concat(colonies).sort_values(by='population', ascending=False).copy()
    elif len(isoconflict) > 0:
        conflicts = []
        for isoc in isoconflict:
            conflicts.append(popd[popd['country_code'] == isoc].copy())
        conflicts.append(popd[popd['country_code'] == iso].copy())
        popc = pd.concat(conflicts).sort_values(by='population', ascending=False).copy()
    else:
        popc = popd[popd['country_code'] == iso].copy().sort_values(by='population', ascending=False)

    poploc = popc.loc[:, ['latitude', 'longitude']].values
    poploc = np.deg2rad(poploc)
    
    r2p = haversine_distances(resloc, poploc)
    r2p *= 6371000/1000
    
    metro = np.zeros(len(r2p), dtype=int)
    matchs = ['' for i in range(len(metro))]
    isom = ['' for i in range(len(metro))]
    diffs = np.zeros(len(metro))

    for i in range(len(metro)):
        argmatch = np.argmin(r2p[i])
        diffs[i] = r2p[i, argmatch]
        matchs[i] = popc.iloc[argmatch, 0]
        isom[i] = popc.iloc[argmatch, 1]
        metro[i] = popc.iloc[argmatch, 2]
        popc.iloc[argmatch, 2] = 0
    for i in range(len(metro)):
        if isom[i] not in isoconflict:
            argmatch = np.nonzero(r2p[i] < 25)[0]
            matches = popc.iloc[argmatch]
            isomatches = matches[matches['country_code'] == isom[i]]
            totmetro = np.sum(isomatches['population'].values)
            metro[i] += totmetro
            popc.loc[isomatches.index, 'population'] = 0
    
    resc['country_code'] = iso
    resc['matched_iso'] = isom
    resc['matched_pop'] = matchs
    resc['dist_difference'] = diffs
    resc['population'] = metro
    
    cdata.append(resc)
    cnone.append(popc[popc['population'] > 0])

# %%
dfred = pd.concat(cdata, ignore_index=True)
print(dfred.shape)
dfred = dfred.iloc[:, [6,1,2,3,0,7,8,9,10,4,5]]
dfred.head()
# Out:
# (6424, 11)
#   country_code      country                           location  score  \
# 0           AF  Afghanistan                 Kabul, Afghanistan      7
# 1           AF  Afghanistan              Kandahar, Afghanistan      3
# 2           AF  Afghanistan  Lashkar Gah, Helmand, Afghanistan      2
# 3           AF  Afghanistan             Jalalabad, Afghanistan      1
# 4           AF  Afghanistan                 Herat, Afghanistan      1
#
#    incountry_rank matched_iso  matched_pop  dist_difference  population  \
# 0               0          AF        Kabul         4.419195     4489112
# 1               1          AF     Kandahar         3.089936      523300
# 2               2          AF  Lashkar Gah         3.883134       43934
# 3               3          AF    Jalalabad         0.612165      271900
# 4               4          AF        Herat         0.657768      586235
#
#     latitude  longitude
# 0  34.555349  69.207486
# 1  31.628871  65.737175
# 2  31.609565  64.408208
# 3  34.428353  70.457802
# 4  34.352865  62.204029

# %%
filename = '../data/merged_research_cities500.csv'
dfred.to_csv(filename, index=False)

# %%
print(len(dfred[dfred['population'] < 1]))
dfred[dfred['population'] < 1].iloc[:50]
# Out:
# 0
# Empty DataFrame
# Columns: [country_code, country, location, score, incountry_rank, matched_iso, matched_pop, dist_difference, population, latitude, longitude]
# Index: []

# %%
dfred[dfred['country_code'] == 'MG'].head(10)
# Out:
#      country_code     country                  location  score  \
# 3586           MG  Madagascar  Antananarivo, Madagascar    235
# 3587           MG  Madagascar     Mahajanga, Madagascar      8
# 3588           MG  Madagascar     Antsirabe, Madagascar      7
# 3589           MG  Madagascar     Toamasina, Madagascar      3
# 3590           MG  Madagascar   Antsiranana, Madagascar      2
# 3591           MG  Madagascar       Toliara, Madagascar      1
# 3592           MG  Madagascar  Fianarantsoa, Madagascar      1
# 3593           MG  Madagascar      Antalaha, Madagascar      1
# 3594           MG  Madagascar     Ambositra, Madagascar      1
#
#       incountry_rank matched_iso   matched_pop  dist_difference  population  \
# 3586               0          MG  Antananarivo         4.850209     1402433
# 3587               1          MG     Mahajanga         3.278990      154657
# 3588               2          MG     Antsirabe         0.908773      237038
# 3589               3          MG     Toamasina         0.882668      206373
# 3590               4          MG   Antsiranana         0.697308       82937
# 3591               5          MG       Toliara         1.930070      122319
# 3592               6          MG  Fianarantsoa         0.286396      176227
# 3593               7          MG      Antalaha         0.644630       59112
# 3594               8          MG     Ambositra         0.709503       30353
#
#        latitude  longitude
# 3586 -18.879190  47.507905
# 3587 -15.692149  46.333686
# 3588 -19.873008  47.029116
# 3589 -18.144281  49.395784
# 3590 -12.323135  49.294283
# 3591 -23.351619  43.685494
# 3592 -21.454615  47.087504
# 3593 -14.906124  50.278549
# 3594 -20.536263  47.245975

# %%
dfred.sort_values(by='dist_difference', ascending=False).head(25)
# Out:
#      country_code                           country  \
# 3903           KZ                        Kazakhstan
# 1774           CO                          Colombia
# 1599           CN                             China
# 4519           OM                              Oman
# 3462           IQ                              Iraq
# 4901           RU                            Russia
# 1203           CL                             Chile
# 1069           CA                            Canada
# 1106           CA                            Canada
# 1765           CO                          Colombia
# 1890           CD  Democratic Republic of the Congo
# 3906           KZ                        Kazakhstan
# 313            AU                         Australia
# 2136           ET                          Ethiopia
# 6538           US                     United States
# 5175           ZA                      South Africa
# 7120           VN                           Vietnam
# 1888           CD  Democratic Republic of the Congo
# 317            AU                         Australia
# 5138           ZA                      South Africa
# 1889           CD  Democratic Republic of the Congo
# 105            AR                         Argentina
# 4978           WS                             Samoa
# 3250           IN                             India
# 5411           SE                            Sweden
#
#                                                location  score  \
# 3903                               Nauchnyi, Kazakhstan      1
# 1774                     Araracuara, Amazonas, Colombia      1
# 1599                                    Delingha, China      1
# 4519                                        Jumah, Oman      3
# 3462                                        Anbar, Iraq      4
# 4901                             Leninskie Gory, Russia      5
# 1203                                    Ohiggins, Chile      1
# 1069                                 W Hill, ON, Canada      5
# 1106                            Calvert Isl, BC, Canada      2
# 1765                                  Caqueta, Colombia      2
# 1890            Binga, Democratic Republic of the Congo      1
# 3906         Zarechnoe Vil, Kostanai Region, Kazakhstan      1
# 313                              Brandon, MB, Australia      1
# 2136                                     Pawe, Ethiopia      2
# 6538                  Denali Natl Pk, AK, United States      3
# 5175                           Derdepoort, South Africa      1
# 7120                          Nghe An Province, Vietnam      5
# 1888            Swiro, Democratic Republic of the Congo      1
# 317                               Umbrae, SA, Australia      1
# 5138                               Lynn E, South Africa      9
# 1889  Rwanguba, N Kivu, Democratic Republic of the C...      1
# 105                       Neuquen, Rio Negro, Argentina      7
# 4978                                   Pago Pago, Samoa      2
# 3250                     Spiti, Himachal Pradesh, India      1
# 5411                                     Abisko, Sweden     34
#
#       incountry_rank matched_iso           matched_pop  dist_difference  \
# 3903              16          KZ               Saykhin      1077.097935
# 1774              44          CO            Miraflores       221.560876
# 1599             394          CN              Yanglong       185.457272
# 4519               5          OM                Hayma'       171.246661
# 3462               8          IQ                   Hit       146.603545
# 4901              56          RU           Yerbogachen       146.052626
# 1203              30          CL              Cochrane       134.598041
# 1069              81          CA              La Ronge       132.569109
# 1106             118          CA          Port McNeill       126.257274
# 1765              35          CO  Cartagena del Chaira       122.708316
# 1890              14          CD               Businga       116.881215
# 3906              19          KZ              Qusmuryn       111.937587
# 313              155          AU                  Hugh       111.118835
# 2136              30          ET                  Bure       106.763126
# 6538             769          US             Talkeetna       103.832847
# 5175              61          ZA            Thabazimbi       102.175512
# 7120              14          VN              Yen Vinh       100.740985
# 1888              12          CD                 Mweka        93.116693
# 317              159          AU           Roxby Downs        90.881590
# 5138              24          ZA             Carnarvon        89.299886
# 1889              13          CD                  Sake        86.964599
# 105               45          AR                 Anelo        86.214887
# 4978               1          WS               Satitoa        83.216230
# 3250             496          IN                Manali        80.892825
# 5411              10          SE                Kiruna        79.723996
#
#       population   latitude   longitude
# 3903        4825  44.724599   34.010742
# 1774        4864  -0.633333  -72.250000
# 1599        2404  37.369470   97.360870
# 4519        1294  21.473533   55.975413
# 3462       31901  32.559761   41.919647
# 4901        2019  61.524010  105.318756
# 1203        2867 -48.466150  -72.559215
# 1069        5671  56.130366 -106.346771
# 1106        2064  51.555873 -128.036517
# 1765        7586   0.869892  -73.841906
# 1890       28919   2.394366   20.423389
# 3906        8049  51.507710   64.047907
# 313          926 -25.274398  133.775136
# 2136       22038  11.336658   36.334459
# 6538         876  63.114800 -151.192606
# 5175       10365 -24.637199   26.402060
# 7120      107082  19.234249  104.920036
# 1888       50675  -4.038333   21.758664
# 317         4616 -30.000232  136.209155
# 5138        5785 -30.559482   22.937506
# 1889       17151  -0.791773   29.045993
# 105         1742 -37.735937  -69.382179
# 4978         522 -14.275632 -170.702036
# 3250        8341  32.246137   78.034916
# 5411       17037  68.349541   18.831241
